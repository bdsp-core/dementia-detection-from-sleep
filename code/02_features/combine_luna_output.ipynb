# %%
import pandas as pd 
import glob

# %%
luna_list = glob.glob('..\spindle_output\*.xlsx')

# %%
luna_list

# %%
luna_df = pd.DataFrame 
for f in luna_list:
    df = pd.read_excel(f) 
    df 
    break

# %%
luna_df

# %%
luna_df = pd.DataFrame(columns=df.columns[1:])
for f in luna_list:
    print(f)
    df = pd.read_excel(f)
    df = df[df.columns[1:]]
    luna_df = pd.concat([luna_df,df])

# %%
luna_df[['ID','CH', 'F', 'AMP', 'CHIRP', 'COUPL_ANGLE', 'COUPL_MAG', 'COUPL_OVERLAP',
       'COUPL_PV', 'DENS', 'DISPERSION', 'DISPERSION_P', 'DUR', 'FFT', 'FRQ',
       'FWHM', 'ISA_M', 'ISA_S', 'ISA_T', 'MINS', 'N', 'N01', 'N02', 'NE',
       'NOSC', 'Q', 'SYMM', 'SYMM2', 'SO', 'SO_AMP', 'SO_DUR', 'SO_NEG_DUR',
       'SO_P2P', 'SO_POS_DUR', 'SO_RATE', 'SO_SLOPE_NEG1', 'SO_SLOPE_NEG2',
       'SO_SLOPE_POS1', 'SO_SLOPE_POS2', 'SO_TH_NEG', 'SO_TH_P2P']].to_csv("../eeg_data/combined_luna_output.csv",index=False)
